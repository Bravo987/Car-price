# %%
#import libraries
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("scrap price.csv")

# %%
data.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.corr()
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_21452\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                         ID  symboling  wheelbase  carlength  carwidth  \
# ID                1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# ...

# %%
data.drop(['ID','symboling'],axis=1,inplace= True)

# %%
data.drop(['wheelbase','carheight','boreratio','peakrpm','highwaympg','citympg'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                        name fueltypes aspiration doornumbers      carbody  \
# 0        alfa-romero giulia       gas        std         two  convertible
# 1       alfa-romero stelvio       gas        std         two  convertible
# 2  alfa-romero Quadrifoglio       gas        std         two    hatchback
# 3               audi 100 ls       gas        std        four        sedan
# 4                audi 100ls       gas        std        four        sedan
#
#   drivewheels enginelocation  carlength  carwidth  curbweight enginetype  \
# 0         rwd          front      168.8      64.1        2548       dohc
# 1         rwd          front      168.8      64.1        2548       dohc
# 2         rwd          front      171.2      65.5        2823       ohcv
# 3         fwd          front      176.6      66.2        2337        ohc
# 4         4wd          front      176.6      66.4        2824        ohc
#
#   cylindernumber  enginesize fuelsystem  stroke  compressionratio  horsepower  \
# ...

# %%
data.shape
# Out:
# (205, 18)

# %%
data.describe()
# Out:
#         carlength    carwidth   curbweight  enginesize      stroke  \
# count  205.000000  205.000000   205.000000  205.000000  205.000000
# mean   174.049268   65.907805  2555.565854  126.907317    3.255415
# std     12.337289    2.145204   520.680204   41.642693    0.313597
# min    141.100000   60.300000  1488.000000   61.000000    2.070000
# 25%    166.300000   64.100000  2145.000000   97.000000    3.110000
# 50%    173.200000   65.500000  2414.000000  120.000000    3.290000
# 75%    183.100000   66.900000  2935.000000  141.000000    3.410000
# max    208.100000   72.300000  4066.000000  326.000000    4.170000
#
#        compressionratio  horsepower         price
# count        205.000000  205.000000    205.000000
# mean          10.142537  104.117073  13276.710571
# std            3.972040   39.544167   7988.852332
# min            7.000000   48.000000   5118.000000
# 25%            8.600000   70.000000   7788.000000
# 50%            9.000000   95.000000  10295.000000
# ...

# %%
data.isnull().sum()
# Out:
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# carlength           0
# carwidth            0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# stroke              0
# compressionratio    0
# horsepower          0
# price               0
# dtype: int64

# %%
data.head()
# Out:
#                        name fueltypes aspiration doornumbers      carbody  \
# 0        alfa-romero giulia       gas        std         two  convertible
# 1       alfa-romero stelvio       gas        std         two  convertible
# 2  alfa-romero Quadrifoglio       gas        std         two    hatchback
# 3               audi 100 ls       gas        std        four        sedan
# 4                audi 100ls       gas        std        four        sedan
#
#   drivewheels enginelocation  carlength  carwidth  curbweight enginetype  \
# 0         rwd          front      168.8      64.1        2548       dohc
# 1         rwd          front      168.8      64.1        2548       dohc
# 2         rwd          front      171.2      65.5        2823       ohcv
# 3         fwd          front      176.6      66.2        2337        ohc
# 4         4wd          front      176.6      66.4        2824        ohc
#
#   cylindernumber  enginesize fuelsystem  stroke  compressionratio  horsepower  \
# ...

# %% [markdown]
# # Encoding

# %%
# Convert categorical values in numbers

# %%
from sklearn import preprocessing

# %%
label_encoder =preprocessing.LabelEncoder()

# %%
data['fueltypes']=label_encoder.fit_transform(data['fueltypes'])
data['aspiration']=label_encoder.fit_transform(data['aspiration'])
data['doornumbers']=label_encoder.fit_transform(data['doornumbers'])
data['carbody']=label_encoder.fit_transform(data['carbody'])
data['drivewheels']=label_encoder.fit_transform(data['drivewheels'])
data['enginelocation']=label_encoder.fit_transform(data['enginelocation'])
data['enginetype']=label_encoder.fit_transform(data['enginetype'])
data['fuelsystem']=label_encoder.fit_transform(data['fuelsystem'])

# %%
data.head()
# Out:
#                        name  fueltypes  aspiration  doornumbers  carbody  \
# 0        alfa-romero giulia          1           0            1        0
# 1       alfa-romero stelvio          1           0            1        0
# 2  alfa-romero Quadrifoglio          1           0            1        2
# 3               audi 100 ls          1           0            0        3
# 4                audi 100ls          1           0            0        3
#
#    drivewheels  enginelocation  carlength  carwidth  curbweight  enginetype  \
# 0            2               0      168.8      64.1        2548           0
# 1            2               0      168.8      64.1        2548           0
# 2            2               0      171.2      65.5        2823           5
# 3            1               0      176.6      66.2        2337           3
# 4            0               0      176.6      66.4        2824           3
#
#   cylindernumber  enginesize  fuelsystem  stroke  compressionratio  \
# ...

# %%
data.corr()
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_21452\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   fueltypes  aspiration  doornumbers   carbody  drivewheels  \
# fueltypes          1.000000   -0.401397     0.191491 -0.147853    -0.132257
# aspiration        -0.401397    1.000000    -0.031792  0.063028     0.066465
# doornumbers        0.191491   -0.031792     1.000000 -0.680358     0.098954
# carbody           -0.147853    0.063028    -0.680358  1.000000    -0.155745
# drivewheels       -0.132257    0.066465     0.098954 -0.155745     1.000000
# enginelocation     0.040070   -0.057191     0.137757 -0.277009     0.147865
# carlength         -0.212679    0.234539    -0.398568  0.334433     0.485649
# ...

# %%
data.drop(['fueltypes','aspiration','doornumbers','carbody','drivewheels','enginelocation','enginetype'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                        name  carlength  carwidth  curbweight cylindernumber  \
# 0        alfa-romero giulia      168.8      64.1        2548           four
# 1       alfa-romero stelvio      168.8      64.1        2548           four
# 2  alfa-romero Quadrifoglio      171.2      65.5        2823            six
# 3               audi 100 ls      176.6      66.2        2337           four
# 4                audi 100ls      176.6      66.4        2824           five
#
#    enginesize  fuelsystem  stroke  compressionratio  horsepower    price
# 0         130           5    2.68               9.0         111  13495.0
# 1         130           5    2.68               9.0         111  16500.0
# 2         152           5    3.47               9.0         154  16500.0
# 3         109           5    3.40              10.0         102  13950.0
# 4         136           5    3.40               8.0         115  17450.0

# %%
data.name.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
data['name'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: name, Length: 147, dtype: int64

# %% [markdown]
# # Univarient Analysis

# %%
sns.displot(x=data.carlength,kde=True)

# %%
sns.histplot(x=data.price,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# positive skewness present in price  mean is greater than median

# %%
data.drop(['name'],axis=1,inplace=True)

# %%
data.drop(['cylindernumber'],axis=1,inplace=True)

# %%
plt.figure(figsize =(25,25),facecolor='white')
plotnum =1
for c in data:
    if(plotnum<13):
        ax=plt.subplot(3,3,plotnum)
        sns.distplot(data[c])
    plotnum+=1
plt.tight_layout()
# Out:
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_21452\2535602007.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[c])
# C:\Users\Vaibhav\AppData\Local\Temp\ipykernel_21452\2535602007.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[c])
# ...

# %% [markdown]
# # Bivarient analysis

# %%
sns.relplot(x='horsepower',y='price',data=data)

# %%
sns.relplot(x='stroke',y='price',data=data)

# %%
sns.pairplot(data)

# %% [markdown]
# # Outlier

# %%
from scipy import stats

# %%
data.corr()
# Out:
#                   carlength  carwidth  curbweight  enginesize  fuelsystem  \
# carlength          1.000000  0.841118    0.877728    0.683360    0.557810
# carwidth           0.841118  1.000000    0.867032    0.735433    0.521434
# curbweight         0.877728  0.867032    1.000000    0.850594    0.611642
# enginesize         0.683360  0.735433    0.850594    1.000000    0.514070
# fuelsystem         0.557810  0.521434    0.611642    0.514070    1.000000
# stroke             0.129533  0.182942    0.168790    0.203129    0.088153
# compressionratio   0.158414  0.181129    0.151362    0.028971   -0.100786
# horsepower         0.552623  0.640732    0.750739    0.809769    0.655638
# price              0.682920  0.759325    0.835305    0.874145    0.526823
#
#                     stroke  compressionratio  horsepower     price
# carlength         0.129533          0.158414    0.552623  0.682920
# carwidth          0.182942          0.181129    0.640732  0.759325
# ...

# %%
#Checking outlier 
sns.boxplot(x='price',data=data)
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x='horsepower',data=data)
# Out:
# <Axes: xlabel='horsepower'>

# %%
sns.boxplot(x='carwidth',data=data)
# Out:
# <Axes: xlabel='carwidth'>

# %%
# Removing outlier from horse power
IQR = stats.iqr(data.horsepower,interpolation ='midpoint')

# %%
print(IQR)
# Out:
# 46.0

# %%
# Min and Max limit calculations

#first quartile (Q1)
Q1 = data.horsepower.quantile(0.25)

Q3 = data.horsepower.quantile(0.75)

min_limit= Q1 -1.5*IQR
max_limit= Q3 +1.5*IQR

# %%
max_limit
# Out:
# 185.0

# %%
min_limit
# Out:
# 1.0

# %%
data.loc[data['horsepower']>max_limit]
# Out:
#      carlength  carwidth  curbweight  enginesize  fuelsystem  stroke  \
# 49       191.7      70.6        3950         326           5    2.76
# 105      170.7      67.9        3139         181           5    3.27
# 126      168.9      65.0        2756         194           5    2.90
# 127      168.9      65.0        2756         194           5    2.90
# 128      168.9      65.0        2800         194           5    2.90
# 129      175.7      72.3        3366         203           5    3.11
#
#      compressionratio  horsepower    price
# 49               11.5         262  36000.0
# 105               7.8         200  19699.0
# 126               9.5         207  32528.0
# 127               9.5         207  34028.0
# 128               9.5         207  37028.0
# 129              10.0         288  31400.5

# %% [markdown]
# # Feature Selection

# %%
x=data[['carlength','carwidth','curbweight','enginesize','stroke','compressionratio','horsepower']]
y=data.price

# %%
x
# Out:
#      carlength  carwidth  curbweight  enginesize  stroke  compressionratio  \
# 0        168.8      64.1        2548         130    2.68               9.0
# 1        168.8      64.1        2548         130    2.68               9.0
# 2        171.2      65.5        2823         152    3.47               9.0
# 3        176.6      66.2        2337         109    3.40              10.0
# 4        176.6      66.4        2824         136    3.40               8.0
# ..         ...       ...         ...         ...     ...               ...
# 200      188.8      68.9        2952         141    3.15               9.5
# 201      188.8      68.8        3049         141    3.15               8.7
# 202      188.8      68.9        3012         173    2.87               8.8
# 203      188.8      68.9        3217         145    3.40              23.0
# 204      188.8      68.9        3062         141    3.15               9.5
#
#      horsepower
# 0           111
# 1           111
# ...

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
## Step 2 Checking the correlation
sns.heatmap(data.drop('price',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Model Creation

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size =0.2)

# %%
# creating model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
y_test# actual values
# Out:
# 150     5348.0
# 61     10595.0
# 137    18620.0
# 126    32528.0
# 101    13499.0
# 183     7975.0
# 179    15998.0
# 158     7898.0
# 110    13860.0
# 138     5118.0
# 24      6229.0
# 130     9295.0
# 90      7099.0
# 85      6989.0
# 124    12764.0
# 104    17199.0
# 19      6295.0
# 68     28248.0
# 17     36880.0
# 181    15750.0
# 67     25552.0
# 36      7295.0
# 157     7198.0
# 170    11199.0
# 73     40960.0
# 39      8845.0
# 74     45400.0
# 125    22018.0
# 177    11248.0
# 65     18280.0
# 182     7775.0
# 12     20970.0
# 123     8921.0
# 186     8495.0
# 29     12964.0
# 66     18344.0
# 26      7609.0
# 6      17710.0
# 160     7738.0
# 80      9959.0
# 18      5151.0
# Name: price, dtype: float64

# %%
y_predict
# Out:
# array([ 5939.63143017, 10768.28169505, 17502.58555702, 25127.04916818,
#        21603.87544096,  9130.68075019, 21563.06310234,  9668.35054529,
#        19281.64411801,  8066.93234041,  5935.13760472, 11532.48558245,
#         7728.2416829 , 10481.85659014, 17237.52820843, 22746.64386834,
#         5934.07938434, 24939.18291971, 27791.69998515, 20493.59153323,
#        24134.14691495,  6454.40588397,  7439.56503087, 14987.15541217,
#        36082.87857488,  9089.9914711 , 35450.15766984, 19224.3438943 ,
#        11308.53913498, 15393.39077157,  8824.65615893, 16788.4440294 ,
#        10720.10281476,  9356.77596855, 17143.18592735, 13633.85993028,
#         6010.50267751, 16481.56635435,  7388.17975397, 11261.60917386,
#          415.42591881])

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)

# %%
r2score
# Out:
# 0.8425942261743955
